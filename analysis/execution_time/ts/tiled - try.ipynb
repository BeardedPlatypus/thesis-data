# %%
# %matplotlib inline

# %%
import json
from pathlib import Path

import pandas as pd
import numpy as np

# %%
RAW_DATA_ROOT_ATTENUATED = Path("C:/Users/Monthy/Documents/projects/thesis/thesis-data-suite/data/raw/forward_deferred")

SCENES_ATTENUATED = { "pipers-alley" : [  "58#1x_1y_1z"
                                        
                                        , "116#1x_1y_2z"
                                        , "116#1x_2y_1z"
                                        , "116#2x_1y_1z"
                                        
                                        , "174#1x_1y_3z"
                                        , "174#1x_3y_1z"
                                        , "174#3x_1y_1z"
                                        
                                        , "232#1x_2y_2z"
                                        , "232#2x_1y_2z"
                                        , "232#2x_2y_1z"
                                        
                                        , "348#1x_2y_3z"
                                        , "348#1x_3y_2z"
                                        , "348#2x_1y_3z"
                                        , "348#2x_3y_1z"
                                        , "348#3x_2y_1z"
                                        , "348#3x_1y_2z"
                                        
                                        , "464#2x_2y_2z"
                                        
                                        , "522#1x_3y_3z"
                                        , "522#3x_1y_3z"
                                        , "522#3x_3y_1z"
                                        
                                        , "696#2x_2y_3z"
                                        , "696#2x_3y_2z"
                                        , "696#3x_2y_2z"
                                        
                                        , "1044#2x_3y_3z"
                                        , "1044#3x_2y_3z"
                                        , "1044#3x_3y_2z"
                                       ]
                     , "ziggurat-city" : [ "65#1x_1y_1z"                             
                                         
                                          , "130#1x_1y_2z"
                                          , "130#1x_2y_1z"
                                          , "130#2x_1y_1z"
                                          
                                          , "195#3x_1y_1z"
                                          , "195#1x_3y_1z"
                                          , "195#1x_1y_3z"
                                          
                                          , "260#1x_2y_2z"
                                          , "260#2x_1y_2z"
                                          , "260#2x_2y_1z"
                                          
                                          , "390#1x_2y_3z"
                                          , "390#1x_3y_2z"
                                          , "390#2x_1y_3z"
                                          , "390#2x_3y_1z"
                                          , "390#3x_2y_1z"
                                          , "390#3x_1y_2z"
                                          , "520#2x_2y_2z"
                                          
                                          , "585#1x_3y_3z"
                                          , "585#3x_1y_3z"
                                          , "585#3x_3y_1z"
                                          
                                          , "780#2x_2y_3z"
                                          , "780#2x_3y_2z"
                                          , "780#3x_2y_2z"
                                          
                                          , "1170#2x_3y_3z"
                                          , "1170#3x_2y_3z"
                                          , "1170#3x_3y_2z"
                                         ]
                     , "spaceship-indoor" : [ "70#1x_1y_1z"
                                             
                                             , "140#1x_1y_2z"
                                             , "140#1x_2y_1z"
                                             , "140#2x_1y_1z"
                                             
                                             , "210#1x_1y_3z"
                                             , "210#1x_3y_1z"
                                             , "210#3x_1y_1z"
                                             
                                             , "280#1x_2y_2z"
                                             , "280#2x_1y_2z"
                                             , "280#2x_2y_1z"
                                             
                                             , "420#1x_2y_3z"
                                             , "420#1x_3y_2z"
                                             , "420#2x_1y_3z"
                                             , "420#2x_3y_1z"
                                             , "420#3x_1y_2z"
                                             , "420#3x_2y_1z"
                                             
                                             , "560#2x_2y_2z"
                                             
                                             , "630#1x_3y_3z"
                                             , "630#3x_1y_3z"
                                             , "630#3x_3y_1z"
                                             
                                             , "840#2x_2y_3z"
                                             , "840#2x_3y_2z"
                                             , "840#3x_2y_2z"
                                             
                                             , "1260#2x_3y_3z"
                                             , "1260#3x_2y_3z"
                                             , "1260#3x_3y_2z"
                                            ]
                    }


RESOLUTIONS_ATTENUATED = [ 160
                          , 320
                          , 640
                          , 960
                          , 1280
                          , 1920
                          , 2560
                         ]

PIPELINE_TYPES = [ "forward"
                 , "deferred" 
                 ]

# %%
RAW_DATA_ROOT_TILED = Path("C:/Users/Monthy/Documents/projects/thesis/thesis-data-suite/data/raw/tiled")

SCENES_TILED = { "pipers-alley" : [  "58#1x_1y_1z"
                                   
                                , "116#1x_1y_2z"
                                , "116#1x_2y_1z"
                                ,  "116#2x_1y_1z"

                                , "174#1x_1y_3z"
                                , "174#1x_3y_1z"
                                , "174#3x_1y_1z"

                                , "232#1x_2y_2z"
                                , "232#2x_1y_2z"
                                , "232#2x_2y_1z"

                                , "348#1x_2y_3z"
                                , "348#1x_3y_2z"
                                , "348#2x_1y_3z"
                                , "348#2x_3y_1z"
                                , "348#3x_2y_1z"
                                , "348#3x_1y_2z"

                                , "464#2x_2y_2z"

                                , "522#1x_3y_3z"
                                , "522#3x_1y_3z"
                                , "522#3x_3y_1z"

                                , "696#2x_2y_3z"
                                , "696#2x_3y_2z"
                                , "696#3x_2y_2z"

                                , "1044#2x_3y_3z"
                                , "1044#3x_2y_3z"
                                , "1044#3x_3y_2z"
                                ]
               , "ziggurat-city" : [ "65#1x_1y_1z"

                                 , "130#1x_1y_2z"
                                 , "130#1x_2y_1z"
                                 , "130#2x_1y_1z"

                                 , "195#3x_1y_1z"
                                 , "195#1x_3y_1z"
                                 , "195#1x_1y_3z"

                                 , "260#1x_2y_2z"
                                 , "260#2x_1y_2z"
                                 , "260#2x_2y_1z"

                                 , "390#1x_2y_3z"
                                 , "390#1x_3y_2z"
                                 , "390#2x_1y_3z"
                                 , "390#2x_3y_1z"
                                 , "390#3x_2y_1z"
                                 , "390#3x_1y_2z"

                                 , "520#2x_2y_2z"

                                 , "585#1x_3y_3z"
                                 , "585#3x_1y_3z"
                                 , "585#3x_3y_1z"

                                 , "780#2x_2y_3z"
                                 , "780#2x_3y_2z"
                                 , "780#3x_2y_2z"

                                 , "1170#2x_3y_3z"
                                 , "1170#3x_2y_3z"
                                 , "1170#3x_3y_2z"
                                 ]
               , "spaceship-indoor" : [ "70#1x_1y_1z"

                                      , "140#1x_1y_2z"
                                      , "140#1x_2y_1z"
                                      , "140#2x_1y_1z"

                                      , "210#1x_1y_3z"
                                      , "210#1x_3y_1z"
                                      , "210#3x_1y_1z"

                                      , "280#1x_2y_2z"
                                      , "280#2x_1y_2z"
                                      , "280#2x_2y_1z"

                                      , "420#1x_2y_3z"
                                      , "420#1x_3y_2z"
                                      , "420#2x_1y_3z"
                                      , "420#2x_3y_1z"
                                      , "420#3x_1y_2z"
                                      , "420#3x_2y_1z"

                                      , "560#2x_2y_2z"

                                      , "630#1x_3y_3z"
                                      , "630#3x_1y_3z"
                                      , "630#3x_3y_1z"

                                      , "840#2x_2y_3z"
                                      , "840#2x_3y_2z"
                                      , "840#3x_2y_2z"

                                      , "1260#2x_3y_3z"
                                      , "1260#3x_2y_3z"
                                      , "1260#3x_3y_2z"
                                      ]
         }

RESOLUTIONS_TILED = [ 640
                     , 960
                     , 1280
                     , 1920
                    ]

TILE_SIZES = [ 8
              , 16
              , 32
              , 64
             ]

PIPELINE_TYPES = ["forward", "deferred"]

# %%
def json_to_dataframe(json_dic : dict) -> pd.DataFrame:
    '''
    Convert a json data file spit out by nTiled into something just slightly more useful
    '''
    # get all functions tracked from first frame
    frames = json_dic["frames"]
    functions = list(x for x in frames[0]["functions"])
    
    # build empty dictionary which will be loaded with data from frames
    data_raw = { fn : {} for fn in functions }    
    frames_i = {}
    
    for f in frames:
        f_i = int(f["frame"])
        frames_i[f_i] = f_i
        for fn in functions:
            if fn in f["functions"]:
                data_raw[fn][f_i] = float(f["functions"][fn])
            
    data_series = {fn : pd.Series(data_raw[fn], name=fn) for fn in functions }
    data_series["index"] = pd.Series(frames_i, name="index")
    
    dataframe = pd.DataFrame(data_series)
    return dataframe

# %%
def retrieve_attenuated_data():
    '''
    Retrieve all data created for deferred shading
    '''
    n_tests = 3
    
    data = {}
    
    pt_dict = {}
    for pt in PIPELINE_TYPES:
        path_pt = RAW_DATA_ROOT_ATTENUATED / Path(pt)
        
        scene_dict = {}
        for scene in SCENES_ATTENUATED:
            path_scene = path_pt / Path(scene)
            
            ld_dict = {}
            for light_def in SCENES_ATTENUATED[scene]:
                path_ld = path_scene / Path(light_def)
                
                res_dict = {}
                for res in RESOLUTIONS_ATTENUATED:
                    path_res = path_ld / Path("{}".format(res))
                    
                    dataframes = []
                    for i in range(n_tests):
                        file_path = path_res / Path("data_{}.json".format(i))
                        
                        with open(str(file_path), 'r') as f:
                            data_json = json.loads(f.read())
                            
                        dataframes.append(json_to_dataframe(data_json))
                        
                    res_dict[res] = dataframes
                ld_dict[light_def] = res_dict
            scene_dict[scene] = ld_dict
        pt_dict[pt] = scene_dict
    
    return pt_dict

# %%
def retrieve_tiled_data():
    '''
    Retrieve all data created for deferred shading
    '''
    n_tests = 3
    
    data = {}
    
    pt_dict = {}
    for pt in PIPELINE_TYPES:
        path_pt = RAW_DATA_ROOT_TILED / Path(pt)
        
        scene_dict = {}
        for scene in SCENES_TILED:
            path_scene = path_pt / Path(scene)
            
            ld_dict = {}
            for light_def in SCENES_TILED[scene]:
                path_ld = path_scene / Path(light_def)
                
                res_dict = {}
                for res in RESOLUTIONS_TILED:
                    path_res = path_ld / Path("{}".format(res))
                    
                    ts_dict = {}
                    for ts in TILE_SIZES:
                        path_ts = path_res / Path("{}".format(ts))                  
                        
                        dataframes = []
                        for i in range(n_tests):
                            file_path = path_ts / Path("data_{}.json".format(i))
                            
                            with open(str(file_path), 'r') as f:
                                data_json = json.loads(f.read())                         
                            
                            dataframes.append(json_to_dataframe(data_json))
                        
                        ts_dict[ts] = dataframes
                    res_dict[res] = ts_dict
                ld_dict[light_def] = res_dict
            scene_dict[scene] = ld_dict
        pt_dict[pt] = scene_dict
    
    return pt_dict

# %%
data_tiled = retrieve_tiled_data()

# %%
data_attenuated = retrieve_attenuated_data()

# %%
data_tiled["forward"]["pipers-alley"]["58#1x_1y_1z"][1920][8][0]
# Out:
#      ForwardTiledShader::loadLightGrid  ForwardTiledShader::renderObjects  \
# 3                             0.032000                          22.624772
# 4                             0.023309                          12.289966
# 5                             0.018963                          10.684041
# 6                             0.018568                          14.149520
# 7                             0.021728                          24.250055
# 8                             0.012642                           1.307653
# 9                             0.023309                          35.068022
# 10                            0.029630                           0.478419
# 11                            0.009481                           4.869132
# 12                            0.028444                          13.554952
# 13                            0.016593                          13.887594
# 14                            0.016198                          14.110409
# 15                            0.016593                          14.288581
# 16                            0.015802                          27.227633
# 17                            0.011062                          18.083541
# 18                            0.010272                          13.617767
# 19                            0.016593                          13.041372
# 20                            0.016988                          13.442360
# 21                            0.029630                          13.743001
# 22                            0.017383                          13.637520
# 23                            0.025284                          13.767100
# 24                            0.048988                          13.620532
# 25                            0.025284                          13.634755
# 26                            0.026469                          13.477125
# 27                            0.024099                          13.897075
# 28                            0.024099                          13.638705
# 29                            0.026864                          13.686113
# 30                            0.017383                          13.968977
# 31                            0.011852                          12.706360
# 32                            0.031605                          13.439594
# ..                                 ...                                ...
# 522                           0.013037                          17.217962
# 523                           0.022914                          17.209665
# 524                           0.013827                          15.810358
# 525                           0.013827                          17.234159
# 526                           0.012642                          16.967098
# 527                           0.014222                          16.540826
# 528                           0.014222                          16.856876
# 529                           0.013432                          17.233369
# 530                           0.012642                          17.821220
# 531                           0.014222                          15.933222
# 532                           0.012247                          17.421023
# 533                           0.012642                          17.375196
# 534                           0.019753                          17.059937
# 535                           0.023704                          16.918505
# 536                           0.012642                          17.241270
# 537                           0.014222                          16.089666
# 538                           0.015802                          17.136184
# 539                           0.013037                          17.465270
# 540                           0.013432                          17.780924
# 541                           0.013432                          16.649468
# 542                           0.011852                          17.404431
# 543                           0.012642                          17.851640
# 544                           0.013827                          15.358013
# 545                           0.013827                          17.077320
# 546                           0.012642                          17.059937
# 547                           0.024494                          15.956926
# 548                           0.013432                          17.185172
# 549                           0.013432                          17.191888
# 550                           0.015012                          17.653714
# 551                                NaN                                NaN
#
#      TiledLightManager::buildGrid  TiledLightManager::clearGrid  \
# 3                        2.563554                      0.170271
# 4                        3.006812                      0.445629
# 5                        3.650367                      0.356345
# 6                        2.309529                      0.223605
# 7                        2.852738                      0.403358
# 8                        2.573035                      0.228345
# 9                        2.183504                      0.260741
# 10                       2.407899                      0.189629
# 11                       2.147949                      0.159605
# 12                       2.005727                      0.154864
# 545                         0.214123    545
# 546                         0.199506    546
# 547                         0.242173    547
# 548                         0.203457    548
# 549                         0.201876    549
# 550                         0.346864    550
# 551                              NaN    551
#
# [549 rows x 6 columns]

# %%
data_tiled["forward"]["pipers-alley"]["58#1x_1y_1z"][1920][8][1][:-1].mean(axis=0)
# Out:
# ForwardTiledShader::loadLightGrid      0.017129
# ForwardTiledShader::renderObjects     17.355323
# TiledLightManager::buildGrid           2.751360
# TiledLightManager::clearGrid           0.196932
# TiledLightManager::finaliseGrid        0.209189
# index                                276.500000
# dtype: float64

# %%
data_tiled["forward"]["pipers-alley"]["58#1x_1y_1z"][1920][8][1].shape
# Out:
# (549, 6)

# %%
x = data_tiled["forward"]["pipers-alley"]["58#1x_1y_1z"][1920][8][1]
x[:-1]
# Out:
#      ForwardTiledShader::loadLightGrid  ForwardTiledShader::renderObjects  \
# 3                             0.019753                          15.976679
# 4                             0.019753                          18.545763
# 5                             0.010667                           7.200389
# 6                             0.022123                          13.620137
# 7                             0.018173                          12.503299
# 8                             0.011852                          11.011152
# 9                             0.040296                          39.563030
# 10                            0.012247                           0.276148
# 11                            0.021728                           0.258370
# 12                            0.009481                          10.753177
# 13                            0.022519                          30.459235
# 14                            0.017383                          13.804236
# 15                            0.016198                          14.047594
# 16                            0.015802                          29.888371
# 17                            0.017383                           0.319605
# 18                            0.011062                           9.637128
# 19                            0.023704                          13.658458
# 20                            0.086123                          13.506360
# 21                            0.011457                          11.594262
# 22                            0.011062                          12.364632
# 23                            0.022123                          12.475644
# 24                            0.012642                          13.347940
# 25                            0.025284                          13.046903
# 26                            0.022519                          11.632583
# 27                            0.021333                           9.381523
# 28                            0.016988                          13.653323
# 29                            0.016988                          13.961866
# 30                            0.015802                          14.125816
# 31                            0.017778                          13.728384
# 32                            0.016593                          13.867446
# ..                                 ...                                ...
# 521                           0.033185                          17.028332
# 522                           0.024494                          16.775888
# 523                           0.013432                          16.395444
# 524                           0.013037                          17.076925
# 525                           0.013037                          17.197023
# 526                           0.013037                          18.145171
# 527                           0.013827                          16.369765
# 528                           0.012247                          17.243641
# 529                           0.012247                          18.011245
# 530                           0.013432                          15.893716
# 531                           0.013037                          17.123542
# 532                           0.013827                          16.829221
# 533                           0.013827                          16.575987
# 534                           0.012642                          17.243641
# 535                           0.012247                          17.338455
# 536                           0.031210                          16.945764
# 537                           0.013037                          17.378752
# 538                           0.025679                          15.738457
# 539                           0.013432                          17.876529
# 540                           0.014222                          15.996432
# 541                           0.020148                          16.963147
# 542                           0.013037                          17.219147
# 543                           0.014222                          15.993666
# 544                           0.015407                          16.841468
# 545                           0.012247                          17.369270
# 546                           0.013037                          16.003543
# 547                           0.033185                          17.058752
# 548                           0.012642                          17.035048
# 549                           0.022519                          17.081666
# 550                           0.012642                          16.779048
#
#      TiledLightManager::buildGrid  TiledLightManager::clearGrid  \
# 3                        2.599109                      0.122074
# 4                        2.500344                      0.267852
# 533                         0.210173    533
# 534                         0.228345    534
# 535                         0.192790    535
# 536                         0.573234    536
# 537                         0.205037    537
# 538                         0.267457    538
# 539                         0.208987    539
# 540                         0.225975    540
# 541                         0.201086    541
# 542                         0.197926    542
# 543                         0.220444    543
# 544                         0.201481    544
# 545                         0.194765    545
# 546                         0.247704    546
# 547                         0.219654    547
# 548                         0.214518    548
# 549                         0.225975    549
# 550                         0.203852    550
#
# [548 rows x 6 columns]

# %%
r = data_tiled["forward"]["ziggurat-city"]["65#1x_1y_1z"][1920][8][1]
r = r.drop(r.index[-1])
#r
col_list = list(x for x in r if x != 'index')
#print(col_list)

#print((v.mean(axis=0))[col_list])

(r.mean(axis=0))[col_list].sum()
#data_tiled["forward"]["ziggurat-city"]["65#1x_1y_1z"][1920][8][1]
# Out:
# 16.425444456116892

# %%
import re

# %%
col_list = list(x for x in r)
col_list
# Out:
# ['ForwardTiledShader::loadLightGrid',
#  'ForwardTiledShader::renderObjects',
#  'TiledLightManager::buildGrid',
#  'TiledLightManager::clearGrid',
#  'TiledLightManager::finaliseGrid',
#  'index']

# %%
list(x for x in r if (x != 'index') and (x != 'ForwardTiledShader::renderObjects'))
# Out:
# ['ForwardTiledShader::loadLightGrid',
#  'TiledLightManager::buildGrid',
#  'TiledLightManager::clearGrid',
#  'TiledLightManager::finaliseGrid']

# %%
df = data_tiled["forward"]["ziggurat-city"]["65#1x_1y_1z"][1920][8][1]
df = df.drop(df.index[-1])
col_list = list(x for x in df if (x != 'index') and (x != 'ForwardTiledShader::renderObjects'))


df.loc[:, 'grid'] = df[col_list].sum(axis=1)
df.loc[:, 'total'] = df[['ForwardTiledShader::renderObjects', 'grid',]].sum(axis=1)

df
# Out:
#      ForwardTiledShader::loadLightGrid  ForwardTiledShader::renderObjects  \
# 3                             0.008691                          20.070305
# 4                             0.018963                          12.962755
# 5                             0.015012                          14.467544
# 6                             0.071111                          24.688968
# 7                             0.007901                           2.256196
# 8                             0.017778                          13.654508
# 9                             0.012642                          26.413411
# 10                            0.015407                           0.360691
# 11                            0.008691                          13.235348
# 12                            0.015407                          14.010853
# 13                            0.015802                          14.769766
# 14                            0.015012                          14.450952
# 15                            0.014222                          13.423792
# 16                            0.019358                          29.551384
# 17                            0.037136                           0.342518
# 18                            0.007901                          12.882953
# 19                            0.015012                          14.271989
# 20                            0.014222                          14.283050
# 21                            0.015012                          14.452137
# 22                            0.013037                          12.785373
# 23                            0.015012                          14.204828
# 24                            0.013827                          13.722063
# 25                            0.013432                          13.758409
# 26                            0.015012                          14.238409
# 27                            0.015407                          14.157816
# 28                            0.016198                          14.504680
# 29                            0.014222                          14.729075
# 30                            0.039506                          14.034162
# 31                            0.026864                          13.933421
# 32                            0.015012                          13.985174
# ..                                 ...                                ...
# 433                           0.014617                          14.117125
# 434                           0.014617                          13.987940
# 435                           0.014617                          13.957125
# 436                           0.035556                          14.253026
# 437                           0.015407                          14.058656
# 5                           0.138667      5  2.358912  16.826456
# 6                           0.146173      6  3.601380  28.290348
# 7                           0.110617      7  2.199307   4.455503
# 8                           0.146963      8  3.473775  17.128283
# 9                           0.127605      9  2.960195  29.373606
# 10                          0.137876     10  2.972442   3.333133
# 11                          0.150518     11  2.113184  15.348531
# 12                          0.151309     12  2.317430  16.328283
# 13                          0.126025     13  2.268443  17.038209
# 14                          0.122074     14  2.295702  16.746653
# 15                          0.128790     15  2.194171  15.617963
# 16                          0.132741     16  2.241578  31.792963
# 17                          0.121679     17  2.561973   2.904492
# 18                          0.106272     18  1.978468  14.861420
# 19                          0.111407     19  2.145974  16.417962
# 20                          0.114173     20  2.051949  16.334999
# 21                          0.134321     21  2.122270  16.574407
# 22                          0.144592     22  3.610071  16.395444
# 23                          0.138271     23  3.271109  17.475937
# 24                          0.119704     24  2.228937  15.951000
# 25                          0.136691     25  2.442270  16.200679
# 26                          0.131951     26  2.141628  16.380036
# 27                          0.129185     27  2.190220  16.348036
# 28                          0.114173     28  2.145183  16.649863
# 29                          0.128000     29  2.071702  16.800777
# 30                          0.131555     30  2.565924  16.600086
# 31                          0.147753     31  2.530763  16.464185
# 32                          0.130370     32  2.376294  16.361469
# ..                               ...    ...       ...        ...
# 433                         0.147358    433  2.465973  16.583098
# 434                         0.143407    434  2.390517  16.378456
# 435                         0.130765    435  2.502714  16.459839
# 436                         0.168691    436  2.386961  16.639987
# 437                         0.128395    437  2.373924  16.432580
# 438                         0.175407    438  2.370764  16.442456
# 439                         0.141827    439  2.391702  16.506851
# 440                         0.120889    440  2.401183  16.534505
# 441                         0.367407    441  2.841282  16.483543
# 442                         0.171457    442  3.886614  16.555444
# 443                         0.137086    443  3.469429  16.562555
# 444                         0.128000    444  2.917529  16.039889
# 445                         0.154074    445  2.890269  16.079395
# 446                         0.131160    446  2.472294  16.437320
# 447                         0.152889    447  2.375504  16.351197
# 448                         0.171062    448  2.332838  16.426259
# 449                         0.144592    449  2.450171  16.828036
# 450                         0.154864    450  2.734615  16.257172
# 451                         0.134321    451  2.776492  16.555839
# 452                         0.146963    452  2.484541  16.376876
# 453                         0.143802    453  2.453726  16.732431
# 454                         0.143802    454  2.552492  16.190012
# 455                         0.137876    455  2.480591  16.238604
# 456                         0.391111    456  2.803356  16.372530
# 457                         0.152889    457  3.565824  16.374111
# 458                         0.157234    458  4.461034  16.837518
# 459                         0.139852    459  3.376985  16.144185
# 460                         0.154074    460  2.422517  16.367790
# 461                         0.126815    461  2.319406  16.016975
# 462                         0.132346    462  2.332443  16.528975
#
# [460 rows x 8 columns]

# %%
df = data_attenuated["forward"]["ziggurat-city"]["65#1x_1y_1z"][1920][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-fdbf953150c8> in <module>()
# ----> 1 df = data_attenuated["forward"]["ziggurat-city"]["65#1x_1y_1z"][1920][1]
#
# NameError: name 'data_attenuated' is not defined

# %%
PIPELINE_TYPES[0].title()
# Out:
# 'Forward'
